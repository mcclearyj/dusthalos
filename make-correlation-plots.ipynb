# %%
import numpy as np
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
% matplotlib inline

# %%
from astropy.table import Table
import fitsio

# %%
pwd
# Out:
# u'/Users/jemcclea/Research/DES_DUST/round2/dusthalos'

# %% [markdown]
# ## Let's examine those input catalogs: star_class and redshift distributions

# %%
galz_cut=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/Sscom_exactArea_galzCut.fits')
full = Table.read('/Users/jemcclea/Research/DES_DUST/round2/catalogs/wiseScosSvm_RMexact.fits')

# %%
full
# Out:
# <Table length=1143950>
#  index           wiseX          ...       probQso        inPhotozCat
#  int64           str22          ...       float64           int64
# -------- ---------------------- ... -------------------- -----------
#     1357    J000326.34-430142.4 ...             0.085743           0
#     1358    J000357.91-425927.1 ...             0.011946           0
#     1359    J000251.32-430906.8 ... 0.014875999999999999           0
#     1360    J000348.27-430423.9 ... 0.030060000000000003           0
#     1361    J000251.09-425542.1 ...             0.012454           0
#     1363    J000320.58-430622.6 ... 0.013775999999999998           0
#     1364    J000358.97-425819.8 ...             0.009025           0
#     1365    J000357.15-430914.2 ...             0.000399           0
#     1366    J000336.86-430634.8 ...             0.007797           0
#     1367    J000358.36-430754.1 ...             0.813484           0
# ...

# %%
_=plt.hist(full['probGal'],bins=1000)

# %%
_=plt.hist(galz_cut['probGal'],bins=100)
np.mean(galz_cut['probGal'])
# Out:
# 0.9386514877449551

# %% [markdown]
# ## CHANGING BIN SIZES CHANGES RESULT
# ### Still using WiseScos catalog and corrected Av estimator

# %%
cd /Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs
# Out:
# /Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs

# %% [markdown]
# ## IF YOU ONLY TAKE TWO REDSHIFT BINS, GET CLOSER TO LITERATURE RESULT

# %%
dd=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_dd2.fits') # The dust signal -- real fg x real background 
dr=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_dr2.fits') # fg x random background
fr=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_fr2.fits') # random fg x background
rr=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_rr2.fits') # random fg x random background

# %%
fig = plt.figure(figsize=(14,7))

### in log space
ax=fig.add_subplot(121)
ax.errorbar(dd['meanR'],dd['kappa']-(dr['kappa']-np.mean(dr['kappa']))-fr['kappa'],yerr=dd['sigma'],label='random subtracted 2 z bins')
ax.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw 2 z bins')
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlim(.1,250)
r = np.logspace(-2,2.7,10)
av2 = 2.4e-3 * (r/3.06)**(-0.84)
ax.plot(r,av2,label='Scaled Menard (2010)')

#Uncomment to get axis in physical scale: kpc
#a=ax.get_xticks().tolist()
#print a
#physical=[a[i]*0.0279 for i in range(len(a))]
#ax.set_xticklabels(physical)

ax.set_xlabel('target separation (kpc)')
ax.set_ylabel('A_v (mag)')
ax.legend()

### in linear space
ax2=fig.add_subplot(122)
ax2.errorbar(dd['meanR'],dd['kappa']-(dr['kappa']-np.mean(dr['kappa'])),yerr=dd['sigma'],label='random subtracted 2 z bins')
ax2.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw 2 z bins')

ax2.set_xlim(0.1,200)
#ax2.set_ylim(-7e-4,0.)
ax2.plot(r,av2,label='scaled Menard (2010)')
ax2.set_xscale('log')
ax2.axhline(0,color='black',linestyle='--',alpha=0.5)
ax2.set_xlabel('target separation (arcmin)')
ax2.legend()
fig.savefig('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/correlationFuncFigures/dust_measurement_2zbin.png')

# %% [markdown]
# # Doing SCOS subtractions

# %%
dd=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dd_orthonorm-vdust.fits') # The dust signal -- real fg x real background 
dr=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dr_orthonorm-vdust.fits') # fg x random background
fr=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_fr_orthonorm-vdust.fits') # random fg x background
rr=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_rr_orthonorm-vdust.fits') # random fg x random background

# %%
dd1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dd_orthonorm-v1.fits') # The dust signal -- real fg x real background 
dr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dr_orthonorm-v1.fits') # fg x random background
fr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_fr_orthonorm-v1.fits') # random fg x background
rr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_rr_orthonorm-v1.fits') # random fg x random background

# %%
dd2=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dd_orthonorm-v2.fits') # The dust signal -- real fg x real background 
dr2=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dr_orthonorm-v2.fits') # fg x random background
fr2=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_fr_orthonorm-v2.fits') # random fg x background
rr2=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_rr_orthonorm-v2.fits') # random fg x random background

# %%
dd3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dd_orthonorm-v3.fits') # The dust signal -- real fg x real background 
dr3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dr_orthonorm-v3.fits') # fg x random background
fr3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_fr_orthonorm-v3.fits') # random fg x background
rr3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_rr_orthonorm-v3.fits') # random fg x random background

# %%
fig = plt.figure(figsize=(14,7))

### in log space
ax=fig.add_subplot(121)
ax.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw')    
ax.errorbar(dd['meanR'],dd['kappa']-fr['kappa'],yerr=dd['sigma'],label='fr sub only')  
ax.errorbar(dd['meanR'],dd['kappa']-fr['kappa']-dr['kappa'] + rr['kappa'],yerr=dd['sigma'],label='LZ++/includes [+ rr]')
 
ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(1e-5,1e-1)
ax.set_xlim(0.1,250)
r = np.logspace(-2,2.7,10)
av2 = 2.4e-3 * (r/3.06)**(-0.84)
ax.plot(r,av2,label='Adjusted Menard (2010)')

ax.legend()
ax.set_xlabel('target impact parameter (arcmin)')

#Uncomment to get axis in physical scale: Mpc
"""
a=ax.get_xticks().tolist()
print a
physical=[a[i]*.1004 for i in range(len(a))] 
ax.set_xticklabels(physical)
ax.set_xlabel('Impact parameter (Mpc)')
ax.set_ylabel('A_v (mag)')
ax.legend()
"""
### in linear space
ax2=fig.add_subplot(122)
ax2.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw')    
ax2.errorbar(dd['meanR'],dd['kappa']-fr['kappa'],yerr=dd['sigma'],label='fr sub only')  
ax2.errorbar(dd['meanR'],dd['kappa']-fr['kappa']-dr['kappa'] + rr['kappa'],yerr=dd['sigma'],label='LZ++/includes [+ rr]')


ax2.set_xlim(0.07,200)
ax2.set_ylim(-5e-4,0.06)
ax2.plot(r,av2,label='Adjusted Menard (2010)')
ax2.set_xscale('log')
ax2.axhline(0,color='black',linestyle='--',alpha=0.5)
ax2.set_xlabel('target impact parameter (arcmin)')
ax2.legend()
fig.savefig('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/correlationFuncFigures/scos-vdust_variousRandoms.png')

# %%
fig = plt.figure(figsize=(14,7))

### in log space
ax=fig.add_subplot(121)
ax.errorbar(dd2['meanR'],dd2['kappa'],yerr=dd2['sigma'],label='raw')    
ax.errorbar(dd2['meanR'],dd2['kappa']-fr2['kappa'],yerr=dd2['sigma'],label='fr sub only')  
ax.errorbar(dd2['meanR'],dd2['kappa']-fr2['kappa']-dr2['kappa'] + rr2['kappa'],yerr=dd2['sigma'],label='LZ++/includes [+ rr]')
 
ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(1e-5,1e-1)
ax.set_xlim(0.1,250)
r = np.logspace(-2,2.7,10)
av2 = 2.4e-3 * (r/3.06)**(-0.84)
ax.plot(r,av2,label='Adjusted Menard (2010)')

ax.legend()
ax.set_xlabel('target impact parameter (arcmin)')

#Uncomment to get axis in physical scale: Mpc
"""
a=ax.get_xticks().tolist()
print a
physical=[a[i]*.1004 for i in range(len(a))] 
ax.set_xticklabels(physical)
ax.set_xlabel('Impact parameter (Mpc)')
ax.set_ylabel('A_v (mag)')
ax.legend()
"""
### in linear space
ax2=fig.add_subplot(122)
ax2.errorbar(dd2['meanR'],dd2['kappa'],yerr=dd2['sigma'],label='raw')    
ax2.errorbar(dd2['meanR'],dd2['kappa']-fr2['kappa'],yerr=dd2['sigma'],label='fr sub only')  
ax2.errorbar(dd2['meanR'],dd2['kappa']-fr2['kappa']-dr2['kappa'] + rr2['kappa'],yerr=dd1['sigma'],label='LZ++/includes [+ rr]')


ax2.set_xlim(0.07,200)
ax2.set_ylim(-5e-4,0.06)
ax2.plot(r,av2,label='Adjusted Menard (2010)')
ax2.set_xscale('log')
ax2.axhline(0,color='black',linestyle='--',alpha=0.5)
ax2.set_xlabel('target impact parameter (arcmin)')
ax2.legend()
fig.savefig('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/correlationFuncFigures/scos-v2_variousRandoms.png')

# %% [markdown]
# ### Just plotting randoms to help inform plots above

# %% [raw]
# fig=plt.figure(figsize=(14,7))
# ax=fig.add_subplot(121)
# ax.errorbar(dr['meanR'],(dr['kappa']-np.mean(dr['kappa'])),yerr=dr['sigma'],label='fg x randBkg')
# ax.errorbar(fr['meanR'],fr['kappa'],yerr=fr['sigma'],label='randFg x bkg')
# ax.set_xscale('log')
# ax.set_yscale('log')
# ax.set_ylim(1e-6,1e-1)
# ax.set_xlim(0.1,250)
# r = np.logspace(-2,2.7,10)
# av2 = 2.4e-3 * (r/1.)**(-0.84)
# ax.plot(r,av2,label='Menard (2010)')
# ax.set_xlabel('target impact parameter (arcmin)')
#
# ax.legend()
# # Try to plot upper axis in physical scale
# #plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True
# #a=ax.get_xticks().tolist()
# #print a
# #physical=[a[i]*.13 for i in range(len(a))]
# #ax.set_xticklabels(physical)
# ax2=fig.add_subplot(122)
# ax2.errorbar(dr['meanR'],(dr['kappa']-np.mean(dr['kappa'])),yerr=dr['sigma'],label='fg x randBkg')
# ax2.errorbar(fr['meanR'],fr['kappa'],yerr=fr['sigma'],label='randFg x bkg')
# ax2.set_xscale('log')
# ax2.set_xlim(0.1,250)
# ax2.set_ylim(-0.005,0.02)
# ax2.plot(r,av2,label='Menard (2010)')
# ax2.axhline(0,color='black',linestyle='--',alpha=0.5)
# ax2.set_xlabel('target separation (arcmin)')
# ax2.legend()
# fig.savefig('correlationFuncFigures/randoms_10zbins.png')

# %% [markdown]
# ## Star-redMaGiC correlation plots

# %%
dd=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/star_correlation_dd10.fits') # The dust signal -- real fg x real background 
dr=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/star_correlation_dr10.fits') # fg x random background
fr=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/star_correlation_fr10.fits') # random fg x background

# %%
fig=plt.figure(figsize=(14,7))

### in log space
ax=fig.add_subplot(121)
ax.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw')    
#ax.errorbar(dd['meanR'],dd['kappa']-(dr['kappa']-np.mean(dr['kappa']))-fr['kappa'],yerr=dd['sigma'],label='[randFg/Bkg - mean(randFg/Bkg)] subtraction')  
ax.errorbar(dd['meanR'],dd['kappa']-fr['kappa'],yerr=dd['sigma'],label='fr sub')
 
ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(1e-5,1e-1)
ax.set_xlim(0.1,250)
r = np.logspace(-2,2.7,10)
av = 2.4e-3 * (r/1.)**(-0.84)
av2 = 2.4e-3 * (r/3.06)**(-0.84)
ax.plot(r,av2,label='Menard (2010) for z=0.15')

ax.legend()
ax.set_xlabel('target impact parameter (arcmin)')

#Uncomment to get axis in physical scale: Mpc
"""
a=ax.get_xticks().tolist()
print a
physical=[a[i]*.1004 for i in range(len(a))] 
ax.set_xticklabels(physical)
ax.set_xlabel('Impact parameter (Mpc)')
ax.set_ylabel('A_v (mag)')
ax.legend()
"""
### in linear space
ax2=fig.add_subplot(122)
ax2.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw')    
#ax2.errorbar(dd['meanR'],dd['kappa']-(dr['kappa']-np.mean(dr['kappa']))-fr['kappa'],yerr=dd['sigma'],label='[randFg/Bkg - mean(randFg/Bkg)] subtraction')  
ax2.errorbar(dd['meanR'],dd['kappa']-fr['kappa'],yerr=dd['sigma'],label='fr sub')


ax2.set_xlim(0.07,200)
ax2.set_ylim(-5e-3,0.01)
ax2.plot(r,av2,label='Menard (2010) for z = 0.15')
ax2.set_xscale('log')
ax2.axhline(0,color='black',linestyle='--',alpha=0.5)
ax2.set_xlabel('target impact parameter (arcmin)')
ax2.legend()
#fig.savefig('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/correlationFuncFigures/dust_corrSTARS.png')

# %% [markdown]
# ## Plotting orthonorm vector dust measurements...

# %%
dd=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_dd_orthonorm-vdust.fits') # The dust signal -- real fg x real background 
dr=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_dr_orthonorm-vdust.fits') # fg x random background
fr=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_fr_orthonorm-vdust.fits') # random fg x background
rr=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_rr_orthonorm-vdust.fits') # random fg x random background

# %%
dd1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_dd_orthonorm-v1.fits') # The dust signal -- real fg x real background 
dr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_dr_orthonorm-v1.fits') # fg x random background
fr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_fr_orthonorm-v1.fits') # random fg x background
rr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_rr_orthonorm-v1.fits') # random fg x random background

# %%
dd3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_dd_orthonorm-v3.fits') # The dust signal -- real fg x real background 
dr3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_dr_orthonorm-v3.fits') # fg x random background
fr3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_fr_orthonorm-v3.fits') # random fg x background
rr3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_rr_orthonorm-v3.fits') # random fg x random background

# %%
ddOpt=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_dd_orthonorm-voptimal.fits') # The dust signal -- real fg x real background 
drOpt=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_dr_orthonorm-voptimal.fits') # fg x random background
frOpt=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_fr_orthonorm-voptimal.fits') # random fg x background
rrOpt=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation_rr_orthonorm-voptimal.fits') # random fg x random background

# %%
dd['kappa']*0.22
# Out:
# <Column name='kappa' dtype='float64' length=13>
#     0.01973203669480323
#   0.0047649737190025195
#   0.0005299638448912588
#  0.00038205666087131457
#   0.0001706338548969529
#  0.00018003669720543616
#   9.108873285372606e-05
#  2.2561529201619764e-05
#    7.24721714727628e-05
#  5.3286144876288894e-05
#  2.1673261641579535e-06
#  1.7840647526208544e-05
# -6.0861488948112046e-05

# %% [raw]
# fig=plt.figure(figsize=(14,14))
# r = np.logspace(-2,2.7,10)
# av2 = 2.4e-3 * (r/3.06)**(-0.84)
#
# ### in log space
#
# ax=fig.add_subplot(221)
# ax.errorbar(dd['meanR'],dd['kappa']*0.458,yerr=dd['sigma']*0.458,label='raw vdust_scaled')
# ax.errorbar(dd1['meanR'],dd1['kappa'],yerr=dd1['sigma'],label='raw v1')
# ax.set_xscale('log')
# ax.set_yscale('log')
# ax.set_ylim(5e-6,2e-1)
# ax.set_xlim(0.1,250)
# ax.plot(r,av2,label='Menard (2010) for z=0.15')
# ax.legend()
# ax.set_xlabel('target impact parameter (arcmin)')
#
# ax2=fig.add_subplot(222)
# ax2.errorbar(dd['meanR'],(dd['kappa']-fr['kappa'])*0.458,yerr=dd['sigma']*0.458,label='fgRand sub vdust_scaled')
# ax2.errorbar(dd1['meanR'],dd1['kappa']-fr1['kappa'],yerr=dd1['sigma'],label='fgRand sub v1')
# ax2.set_xscale('log')
# ax2.set_yscale('log')
# ax2.set_ylim(5e-6,2e-1)
# ax2.set_xlim(0.1,250)
# ax2.plot(r,av2,label='Menard (2010) for z=0.15')
#
# ax2.legend()
# ax2.set_xlabel('target impact parameter (arcmin)')
#
#
# ### in linear space
# ax3=fig.add_subplot(223)
# ax3.errorbar(dd['meanR'],dd['kappa']*0.458,yerr=dd['sigma']*0.458,label='raw vdust_scaled')
# ax3.errorbar(dd1['meanR'],dd1['kappa'],yerr=dd1['sigma'],label='raw v1')
# ax3.set_xlim(.1,200)
# ax3.set_ylim(-1e-3,0.06)
# ax3.plot(r,av2,label='Menard (2010) for z = 0.15')
# ax3.set_xscale('log')
# ax3.axhline(0,color='black',linestyle='--',alpha=0.5)
# ax3.set_xlabel('target impact parameter (arcmin)')
# ax3.legend()
#
# ax4=fig.add_subplot(224)
# ax4.errorbar(dd['meanR'],(dd['kappa']-fr['kappa'])*0.458,yerr=dd['sigma']*0.458,label='fgRand sub vdust_scaled')
# ax4.errorbar(dd1['meanR'],dd1['kappa']-fr1['kappa'],yerr=dd1['sigma'],label='fgRand sub v1')
# ax4.set_xlim(.1,200)
# ax4.set_ylim(-1e-3,0.06)
# ax4.plot(r,av2,label='Menard (2010) for z = 0.15')
# ax4.set_xscale('log')
# ax4.axhline(0,color='black',linestyle='--',alpha=0.5)
# ax4.set_xlabel('target impact parameter (arcmin)')
# ax4.legend()
#
# fig.savefig('dustOrthonorm_scaledVdustV0.png')

# %%
fig=plt.figure(figsize=(14,14))
r = np.logspace(-2,2.7,10)
av2 = 2.4e-3 * (r/3.06)**(-0.84)

### in log space

ax=fig.add_subplot(221)
ax.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw vdust_scaled')  
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim(5e-6,2e-1)
ax.set_xlim(0.1,250)
ax.plot(r,av2,label='Menard (2010) for z=0.09')
ax.legend()
ax.set_xlabel('target impact parameter (arcmin)')

ax2=fig.add_subplot(222)
ax2.errorbar(dd['meanR'],(dd['kappa']-fr['kappa']),yerr=dd['sigma'],label='fgRand sub vdust_scaled')  
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_ylim(5e-6,2e-1)
ax2.set_xlim(0.1,250)
ax2.plot(r,av2,label='Menard (2010) for z=0.09')

ax2.legend()
ax2.set_xlabel('target impact parameter (arcmin)')


### in linear space
ax3=fig.add_subplot(223) 
ax3.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw vdust_scaled')  
ax3.set_xlim(.1,200)
ax3.set_ylim(-1e-3,0.06)
ax3.plot(r,av2,label='Menard (2010) for z = 0.15')
ax3.set_xscale('log')
ax3.axhline(0,color='black',linestyle='--',alpha=0.5)
ax3.set_xlabel('target impact parameter (arcmin)')
ax3.legend()

ax4=fig.add_subplot(224)
ax4.errorbar(dd['meanR'],(dd['kappa']-fr['kappa']),yerr=dd['sigma'],label='fgRand sub vdust_scaled')  
ax4.errorbar(dd3['meanR'],(dd3['kappa']-fr3['kappa'])*-13.15,yerr=dd3['sigma']*13.15,label='fgRand sub v3')  
ax4.set_xlim(.1,200)
ax4.set_ylim(-1e-3,0.06)
ax4.plot(r,av2,label='Menard (2010) for z = 0.15')
ax4.set_xscale('log')
ax4.axhline(0,color='black',linestyle='--',alpha=0.5)
ax4.set_xlabel('target impact parameter (arcmin)')
ax4.legend()

#fig.savefig('dustOrthonorm_scaledVdustV0.png')

# %% [markdown]
# ### SCOS: what does this "optimal dust vector" look like if you just add all scaled components?

# %% [raw]
# fig = plt.figure(figsize=(6,6))
# r = np.logspace(-2,2.7,10)
#
#
# ### in log space
# ax=fig.add_subplot(111)
# ax.errorbar(dd['meanR'],(dd['kappa']-fr['kappa'])*.22,yerr=dd['sigma']*.22,label='SCos x redMaGiC',fmt='o',ms=6, mew=6)
#
# ax.FontSize = 16
# #plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
# #plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True
# #ax.xaxis.set_ticks_position('top')
#
# plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
# plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
# ax.xaxis.set_ticks_position('bottom')
# ax.xaxis.set_tick_params(labelsize=16)
# ax.yaxis.set_tick_params(labelsize=16)
#
# a=ax.get_xticks().tolist()
# physical=[a[i]*.101 for i in range(len(a))]
# print a
# print physical
# ax.set_yscale('log')
# ax.set_xscale('log')
#
# ax.set_ylim(1E-6,1E-2)
# ax.set_xlim(.1,250)
# ax.set_xticklabels(physical)
# ax.set_xlabel('Impact parameter (Mpc)',fontsize=16)
#
# #ax.set_xlabel('Impact parameter (arcmin)',fontsize=16)
# ax.set_ylabel('dust surface mass',fontsize=16)
# #ax.set_title('arcmin')
# fig.tight_layout()
# fig.savefig('dustCorrel_dustmass.eps',transparent=True)

# %%
dd['meanR']
# Out:
# <Column name='meanR' dtype='float64' length=13>
#  0.1521441688400707
#  0.2689673538172902
# 0.48260567268850935
#  0.8769247743914256
#  1.5984207385231801
#  2.9105964078387636
#   5.307625972355579
#      9.673577615713
#   17.61985646690408
#   32.09563096070563
#  58.446351336156965
#  106.38920713092111
#   193.6101614526299

# %%
fig = plt.figure(figsize=(7,7))
r = np.logspace(-2,2.7,10)
av2 = 2.4e-3 * (r/3.06)**(-0.84)
    
### in log space
ax=fig.add_subplot(111)
ax.errorbar(dd['meanR'],(dd['kappa']-fr['kappa']),yerr=dd['sigma'],label='SCos x redMaGiC',fmt='o',ms=6, mew=6)
ax.plot(r,av2,label='Menard (2010) for z = 0.09')
ax.legend()
ax.plot(dd['meanR'],(dd['kappa']-fr['kappa']),'--k')  
ax.FontSize = 16
#ax.xaxis.set_ticks_position('top')
ax.xaxis.set_ticks_position('bottom')

ax.set_xlim(0.1,200)
ax.set_yscale('log')
ax.set_xscale('log')

plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
ax.xaxis.set_label_position('bottom')
ax.xaxis.set_tick_params(labelsize=16)
ax.yaxis.set_tick_params(labelsize=16)

a=ax.get_xticks().tolist()
physical=[a[i]*.101 for i in range(len(a))] 
print a
print physical


#ax.set_ylim(1E-6,1E-2)
#ax.set_xticklabels(physical)
#ax.set_xlabel('Impact parameter (Mpc)',fontsize=16)
ax.set_xlabel('Impact parameter (arcmin)',fontsize=16)
ax.set_ylabel('extinction (Av)',fontsize=16)

fig.tight_layout()
fig.savefig('dustCorrel2.eps',transparent=False)
# Out:
# [0.01, 0.1, 1.0, 10.0, 100.0, 1000.0, 10000.0]
# [0.00101, 0.010100000000000001, 0.101, 1.01, 10.100000000000001, 101.0, 1010.0000000000001]

# %% [markdown]
# # Galex correlations

# %%
dd=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dd_orthonorm-vdust-galex.fits') # The dust signal -- real fg x real background 
dr=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dr_orthonorm-vdust-galex.fits') # fg x random background
fr=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_fr_orthonorm-vdust-galex.fits') # random fg x background
rr=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_rr_orthonorm-vdust-galex.fits') # random fg x random background

dd1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dd_orthonorm-v1-galex.fits') # The dust signal -- real fg x real background 
dr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dr_orthonorm-v1-galex.fits') # fg x random background
fr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_fr_orthonorm-v1-galex.fits') # random fg x background
rr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_rr_orthonorm-v1-galex.fits') # random fg x random background

ddOpt=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dd_orthonorm-voptimal-galex.fits') # The dust signal -- real fg x real background 
drOpt=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dr_orthonorm-voptimal-galex.fits') # fg x random background
frOpt=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_fr_orthonorm-voptimal-galex.fits') # random fg x background
rrOpt=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_rr_orthonorm-voptimal-galex.fits') # random fg x random background

# %%
fig=plt.figure(figsize=(14,14))
r = np.logspace(-2,2.7,10)
av2 = 2.4e-3 * (r/3.06)**(-0.84)

### in log space

ax=fig.add_subplot(221)
ax.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw "vdust"')
ax.errorbar(dd['meanR'],dd['kappa']-fr['kappa'],yerr=dd['sigma'],label='fr sub only')
ax.errorbar(dd['meanR'],dd['kappa']-fr['kappa']-dr['kappa']+rr['kappa'],yerr=dd['sigma'],label='LZ++')  
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim(5e-6,2e-1)
ax.set_xlim(0.1,250)
ax.plot(r,av2,label='Menard (2010) for z=0.15')
ax.legend()
ax.set_xlabel('target impact parameter (arcmin)')

ax2=fig.add_subplot(222)
ax2.errorbar(ddOpt['meanR'],ddOpt['kappa'],yerr=ddOpt['sigma'],label='raw "Voptimal"')
ax2.errorbar(ddOpt['meanR'],ddOpt['kappa']-frOpt['kappa'],yerr=ddOpt['sigma'],label='fr sub only')
ax2.errorbar(ddOpt['meanR'],ddOpt['kappa']-frOpt['kappa']-drOpt['kappa']+rrOpt['kappa'],yerr=ddOpt['sigma'],label='LZ++')  
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_ylim(5e-6,2e-1)
ax2.set_xlim(0.1,250)
ax2.plot(r,av2,label='Menard (2010) for z=0.15')

ax2.legend()
ax2.set_xlabel('target impact parameter (arcmin)')


### in linear space
ax3=fig.add_subplot(223) 
ax3.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw "vdust"')
ax3.errorbar(dd['meanR'],dd['kappa']-fr['kappa'],yerr=dd['sigma'],label='fr sub only')
ax3.errorbar(dd['meanR'],dd['kappa']-fr['kappa']-dr['kappa']+rr['kappa'],yerr=dd['sigma'],label='LZ++')  
ax3.set_xlim(.1,200)
ax3.set_ylim(-5e-3,0.04)
ax3.plot(r,av2,label='Menard (2010) for z = 0.15')
ax3.set_xscale('log')
ax3.axhline(0,color='black',linestyle='--',alpha=0.5)
ax3.set_xlabel('target impact parameter (arcmin)')
ax3.legend()

ax4=fig.add_subplot(224)
ax4.errorbar(ddOpt['meanR'],ddOpt['kappa'],yerr=ddOpt['sigma'],label='raw "voptimal"')
ax4.errorbar(ddOpt['meanR'],ddOpt['kappa']-frOpt['kappa'],yerr=ddOpt['sigma'],label='fr sub only')
ax4.errorbar(ddOpt['meanR'],ddOpt['kappa']-frOpt['kappa']-drOpt['kappa']+rrOpt['kappa'],yerr=ddOpt['sigma'],label='LZ++')  
ax4.set_xlim(.1,200)
ax4.set_ylim(-5e-3,0.04)
ax4.plot(r,av2,label='Menard (2010) for z = 0.15')
ax4.set_xscale('log')
ax4.axhline(0,color='black',linestyle='--',alpha=0.5)
ax4.set_xlabel('target impact parameter (arcmin)')
ax4.legend()

fig.savefig('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/correlationFuncFigures/galex_vopt-vs-vdust.png')

# %% [markdown]
# # IIFSCz correlations

# %%
dd=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dd_orthonorm-vdust-iifsc.fits') # The dust signal -- real fg x real background 
dr=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dr_orthonorm-vdust-iifsc.fits') # fg x random background
fr=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_fr_orthonorm-vdust-iifsc.fits') # random fg x background
rr=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_rr_orthonorm-vdust-iifsc.fits') # random fg x random background

dd1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dd_orthonorm-v1-iifsc.fits') # The dust signal -- real fg x real background 
dr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_dr_orthonorm-v1-iifsc.fits') # fg x random background
fr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_fr_orthonorm-v1-iifsc.fits') # random fg x background
rr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dustCorr_rr_orthonorm-v1-iifsc.fits') # random fg x random background

# %%
fig=plt.figure(figsize=(14,14))
r = np.logspace(-2,2.7,10)
av2 = 2.4e-3 * (r/13.0)**(-0.84)

### in log space

ax=fig.add_subplot(221)
ax.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw vdust NOT scaled')  
ax.errorbar(dd1['meanR'],dd1['kappa'],yerr=dd1['sigma'],label='raw v1')  
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim(5e-6,2e-1)
ax.set_xlim(0.1,250)
ax.plot(r,av2,label='Menard (2010) for z=0.09')
ax.legend()
ax.set_xlabel('target impact parameter (arcmin)')

ax2=fig.add_subplot(222)
ax2.errorbar(dd['meanR'],(dd['kappa']-fr['kappa'])*1.163,yerr=dd['sigma']*1.163,label='fgRand sub vdust_scaled')  
ax2.errorbar(dd1['meanR'],dd1['kappa']-fr1['kappa'],yerr=dd1['sigma'],label='fgRand sub v1')  
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_ylim(5e-6,2e-1)
ax2.set_xlim(0.1,250)
ax2.plot(r,av2,label='Menard (2010) for z=0.09')

ax2.legend()
ax2.set_xlabel('target impact parameter (arcmin)')


### in linear space
ax3=fig.add_subplot(223) 
ax3.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw vdust NOT scaled')  
ax3.errorbar(dd1['meanR'],dd1['kappa'],yerr=dd1['sigma'],label='raw v1')  
ax3.set_xlim(.1,200)
ax3.set_ylim(-2e-2,0.06)
ax3.plot(r,av2,label='Menard (2010) for z = 0.09')
ax3.set_xscale('log')
ax3.axhline(0,color='black',linestyle='--',alpha=0.5)
ax3.set_xlabel('target impact parameter (arcmin)')
ax3.legend()

ax4=fig.add_subplot(224)
ax4.errorbar(dd['meanR'],(dd['kappa']-fr['kappa'])*1.163,yerr=dd['sigma']*1.163,label='fgRand sub vdust_scaled')  
ax4.errorbar(dd1['meanR'],dd1['kappa']-fr1['kappa'],yerr=dd1['sigma'],label='fgRand sub v1')  
ax4.set_xlim(.1,200)
ax4.set_ylim(-2e-2,0.06)
ax4.plot(r,av2,label='Menard (2010) for z = 0.09')
ax4.set_xscale('log')
ax4.axhline(0,color='black',linestyle='--',alpha=0.5)
ax4.set_xlabel('target impact parameter (arcmin)')
ax4.legend()

fig.savefig('dustOrthonorm_scaledVdustV0-iifsc.png')

# %% [raw]
# ### Just a shade confused by large-scale behavior
# fig=plt.figure(figsize=(14,7))
# r = np.logspace(-2,2.7,10)
# av2 = 2.4e-3 * (r/3.06)**(-0.84)
#
# ### in linear space
# ax3=fig.add_subplot(121)
# ax3.errorbar(dd['meanR'],dd['kappa'],yerr=dd['sigma'],label='raw vdust')
# ax3.errorbar(dd1['meanR'],dd1['kappa'],yerr=dd1['sigma'],label='raw v1')
# ax3.set_xlim(1,200)
# ax3.set_ylim(-5e-3,0.005)
# ax3.plot(r,av2,label='Menard (2010) for z = 0.15')
# ax3.set_xscale('log')
# ax3.axhline(0,color='black',linestyle='--',alpha=0.5)
# ax3.set_xlabel('target impact parameter (arcmin)')
# ax3.legend()
#
# ax4=fig.add_subplot(122)
# ax4.errorbar(dd['meanR'],(dd['kappa']-fr['kappa']),yerr=dd['sigma'],label='fgRand sub vdust')
# ax4.errorbar(dd1['meanR'],dd1['kappa']-fr1['kappa'],yerr=dd1['sigma'],label='fgRand sub v1')
# ax4.set_xlim(1,200)
# ax4.set_ylim(-5e-3,0.005)
# ax4.plot(r,av2,label='Menard (2010) for z = 0.15')
# ax4.set_xscale('log')
# ax4.axhline(0,color='black',linestyle='--',alpha=0.5)
# ax4.set_xlabel('target impact parameter (arcmin)')
# ax4.legend()
#
#
# fig.savefig('dustOrthonorm_scaledVdustV0_largeTheta-galex.png')

# %% [markdown]
# # Plot fiducial vs. "best-fit" dust vectors against each other

# %%
def get_ONbasis(vdust):
    # construct an orthonormal set of basis vectors according
    # to the Gram-Schmidt procedure: define V={v0,v1,v2,v3}
    # that spans the "extinction" basis

    # right now, we have a single vector along which (we think) reddening occurs
    # so define ON basis vectors along which we can project the (real?) vector

    # start by normalizing the input dust vector
    vec = vdust#/norm(vdust)
    
    # Go through the G-S process
    v0 = np.zeros_like(vec); v0[0]= 1.0
    v0prime = v0 - np.dot(v0,vec)*vec
    u0 = v0prime/norm(v0prime)

    v1 = np.zeros_like(vec); v1[1]= 1.0
    v1prime = v1 - np.dot(v1,vec)*vec - np.dot(v1,u0)*u0
    u1 = v1prime/norm(v1prime)

    v2 = np.zeros_like(vec); v2[2]= 1.0
    v2prime = v2 - np.dot(v2,vec)*vec - np.dot(v2,u0)*u0 - np.dot(v2,u1)*u1
    u2 = v2prime/norm(v2prime)

    # Return basis
    return vec,u0,u1,u2

# %%
vdust = np.array([1.12224688, 0.82747095, 0.62680647, 0.47880753])

# %%
from numpy.linalg import norm

basis=get_ONbasis(vdust)
fid=basis[0]#/norm(basis[0])

## Coefficients obtained by eval_chi2.py on the kfid/k1/k2/k3 obtained by running dust_measurement.py
## with the "standard" ON_basis vectors
#new=basis[0]+0.458*basis[1]-0.076*basis[3]
#new=basis[0]+0.665*basis[1]-0.22*basis[2]-0.23*basis[3]
new=basis[0]-0.315*basis[1]+0.09*basis[2]-0.15*basis[3]
new_norm=new/1.19#/norm(new)


# define array of central wavelengths for plotting 
wl=np.array([475.4,620.4,769.8,966.5])

fig=plt.figure(figsize=(7,7))
ax=fig.add_subplot(111)
ax.plot(wl, fid,'.b',markersize=15,label='fiducial dust vector')
ax.plot(wl, fid,'--k')
ax.plot(wl, new_norm, '.r',markersize=15,label='true (?) dust vector')
ax.plot(wl, new_norm,'--k')

ax.axvline(537.7)
ax.axhline(1)

ax.set_xlabel('wavelength',fontsize=16)
ax.set_ylabel('A_lambda/A_V',fontsize=16)
for tick in ax.xaxis.get_major_ticks():  
 tick.label.set_fontsize(16)
for tick in ax.yaxis.get_major_ticks():
 tick.label.set_fontsize(16)

ax.legend()

#fig.savefig('dust_vectors_fidVsTrue_Norm.png')

# %%
## Let's normalize

# %% [markdown]
# ## Dumb color correlation plots...

# %%
dd=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/colorcorr1/color_correlation_dd_orthonorm-vdust.fits') # The dust signal -- real fg x real background 
dr=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/colorcorr1/color_correlation_dr_orthonorm-vdust.fits') # fg x random background
fr=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/colorcorr1/color_correlation_fr_orthonorm-vdust.fits') # random fg x background
rr=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/colorcorr1/color_correlation_rr_orthonorm-vdust.fits') # random fg x random background

# %%
dd2=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/color_correlation_dd_orthonorm-vdust.fits') # The dust signal -- real fg x real background 
dr2=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/color_correlation_dr_orthonorm-vdust.fits') # fg x random background
fr2=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/color_correlation_fr_orthonorm-vdust.fits') # random fg x background
rr2=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/color_correlation_rr_orthonorm-vdust.fits') # random fg x random background

# %%
dd3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/colorcorr2/color_correlation_dd_orthonorm-vdust.fits') # The dust signal -- real fg x real background 
dr3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/colorcorr2/color_correlation_dr_orthonorm-vdust.fits') # fg x random background
fr3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/colorcorr2/color_correlation_fr_orthonorm-vdust.fits') # random fg x background
rr3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/colorcorr2/color_correlation_rr_orthonorm-vdust.fits') # random fg x random background

# %%
dd2
# Out:
# array([(1.34985881e-01, 1.50942636e-01, -1.90193785, 1.77632062, 2.14945477e-01, 6.50000000e+01, 6.50000000e+01),
#        (2.45960311e-01, 2.69477429e-01, -1.32268452, 1.74109979, 7.42312439e-02, 5.45000000e+02, 5.45000000e+02),
#        (4.48168907e-01, 4.83755750e-01, -0.73935506, 1.73390443, 3.65743668e-02, 2.24500000e+03, 2.24500000e+03),
#        (8.16616991e-01, 8.79927379e-01, -0.14154473, 1.73181962, 2.00370688e-02, 7.48000000e+03, 7.48000000e+03),
#        (1.48797317e+00, 1.60007810e+00,  0.45641388, 1.73160312, 1.11024700e-02, 2.43630000e+04, 2.43630000e+04),
#        (2.71126389e+00, 2.91221632e+00,  1.05525773, 1.73230805, 6.16730136e-03, 7.89550000e+04, 7.89550000e+04),
#        (4.94024491e+00, 5.30996229e+00,  1.65585408, 1.73210542, 3.41069619e-03, 2.58157000e+05, 2.58157000e+05),
#        (9.00171313e+00, 9.67156003e+00,  2.25553013, 1.73180761, 1.88407090e-03, 8.46010000e+05, 8.46010000e+05),
# ...

# %%
dr2
# Out:
# array([(1.34985881e-01, 1.45043400e-01, -1.94421842, 1.73871652, 1.88435525e-02, 8.53200000e+03, 8.53200000e+03),
#        (2.45960311e-01, 2.64107822e-01, -1.34524291, 1.73934078, 1.03470848e-02, 2.82970000e+04, 2.82970000e+04),
#        (4.48168907e-01, 4.81413413e-01, -0.74468734, 1.73942601, 5.75419768e-03, 9.14970000e+04, 9.14970000e+04),
#        (8.16616991e-01, 8.77210300e-01, -0.14467432, 1.73909115, 3.18265939e-03, 2.99086000e+05, 2.99086000e+05),
#        (1.48797317e+00, 1.59831509e+00,  0.45528346, 1.7390775 , 1.76403447e-03, 9.73559000e+05, 9.73559000e+05),
#        (2.71126389e+00, 2.91183130e+00,  1.05511877, 1.73898443, 9.78327199e-04, 3.16525100e+06, 3.16525100e+06),
#        (4.94024491e+00, 5.30687013e+00,  1.65533639, 1.73901141, 5.41466675e-04, 1.03331550e+07, 1.03331550e+07),
#        (9.00171313e+00, 9.67169092e+00,  2.25555883, 1.73902347, 2.99179246e-04, 3.38464780e+07, 3.38464780e+07),
# ...

# %%
plt.figure(figsize=(7,7))
#plt.plot(dd['meanR'],(dd['kappa']-dr['kappa']),label='zBin 1')
#plt.plot(dd2['meanR'],(dd2['kappa']-dr2['kappa']),label='zBin 2')
plt.plot(dd3['meanR'],(dd3['kappa']-dr3['kappa']),label='zBin 3')
plt.legend()
plt.xscale('log')
#plt.ylim(1.46,1.50)

# %% [markdown]
# ## SPATIAL CORRELATION FUNCTIONS

# %%
xi1=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/xi1.txt',format='ascii') 
xi2=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/xi2.txt',format='ascii') 
xi3=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/xi3.txt',format='ascii') 
xi4=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/xi4.txt',format='ascii') 
xi5=Table.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/xi5.txt',format='ascii')

# %%
r=dd['meanR']

# %%
fig = plt.figure(figsize=(7,7))
ax=fig.add_subplot(111)
#ax.errorbar(dd['meanR'],dd['DD'],label='raw')    
ax.errorbar(r,xi1['col1'],yerr=xi1['col2'],label='zBin1')  
ax.errorbar(r,xi2['col1'],yerr=xi2['col2'],label='zBin2')  
ax.errorbar(r,xi3['col1'],yerr=xi3['col2'],label='zBin3')  
ax.errorbar(r,xi4['col1'],yerr=xi4['col2'],label='zBin4')  
ax.errorbar(r,xi5['col1'],yerr=xi5['col2'],label='zBin5')  
ax.set_xscale('log')
ax.set_xlim(0.1,200)

for tick in ax.xaxis.get_major_ticks():  
 tick.label.set_fontsize(16)
for tick in ax.yaxis.get_major_ticks():
 tick.label.set_fontsize(16)

ax.set_xlabel('target impact parameter (arcmin)',fontsize=16)
ax.set_ylabel('spatial correlation function',fontsize=16)
ax.legend(fontsize=16)
fig.tight_layout()
fig.savefig('spatial_correlFunc_zbins.png')

# %%
fig = plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
#ax.errorbar(dd['meanR'],dd['DD'],label='raw')    
ax.errorbar(r,xi1['col1'],yerr=xi1['col2'],label='zBin1')  
ax.errorbar(r,xi2['col1'],yerr=xi2['col2'],label='zBin2')  
ax.errorbar(r,xi3['col1'],yerr=xi3['col2'],label='zBin3')  
ax.errorbar(r,xi4['col1'],yerr=xi4['col2'],label='zBin4')  
ax.errorbar(r,xi5['col1'],yerr=xi5['col2'],label='zBin5')  
ax.set_xscale('log')
ax.set_xlim(0.1,200)

for tick in ax.xaxis.get_major_ticks():  
 tick.label.set_fontsize(16)
for tick in ax.yaxis.get_major_ticks():
 tick.label.set_fontsize(16)

ax.set_xlabel('target impact parameter (arcmin)',fontsize=16)
ax.set_ylabel('spatial correlation function',fontsize=16)


ax.legend(fontsize=16)
fig.savefig('spatial_correlFunc_zbins.png')

# %%
### K, not sure what to make of that, so let's look at individual dust correlation functions
dd1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation1_dd_orthonorm-vdust.fits') # The dust signal -- real fg x real background 
dr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation1_dr_orthonorm-vdust.fits') # fg x random background
fr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation1_fr_orthonorm-vdust.fits') # random fg x background
rr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation1_rr_orthonorm-vdust.fits') # random fg x random background

dd2=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation2_dd_orthonorm-vdust.fits') # The dust signal -- real fg x real background 
dr2=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation2_dr_orthonorm-vdust.fits') # fg x random background
fr2=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation2_fr_orthonorm-vdust.fits') # random fg x background
rr2=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation2_rr_orthonorm-vdust.fits') # random fg x random background

dd3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation3_dd_orthonorm-vdust.fits') # The dust signal -- real fg x real background 
dr3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation3_dr_orthonorm-vdust.fits') # fg x random background
fr3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation3_fr_orthonorm-vdust.fits') # random fg x background
rr3=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation3_rr_orthonorm-vdust.fits') # random fg x random background

dd4=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation4_dd_orthonorm-vdust.fits') # The dust signal -- real fg x real background 
dr4=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation4_dr_orthonorm-vdust.fits') # fg x random background
fr4=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation4_fr_orthonorm-vdust.fits') # random fg x background
rr4=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation4_rr_orthonorm-vdust.fits') # random fg x random background

dd5=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation5_dd_orthonorm-vdust.fits') # The dust signal -- real fg x real background 
dr5=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation5_dr_orthonorm-vdust.fits') # fg x random background
fr5=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation5_fr_orthonorm-vdust.fits') # random fg x background
rr5=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation5_rr_orthonorm-vdust.fits') # random fg x random backgroun5
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-78-0b176ecab1a2> in <module>()
#       1 ### K, not sure what to make of that, so let's look at individual dust correlation functions
# ----> 2 dd1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation1_dd_orthonorm-vdust.fits') # The dust signal -- real fg x real background
#       3 dr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation1_dr_orthonorm-vdust.fits') # fg x random background
#       4 fr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation1_fr_orthonorm-vdust.fits') # random fg x background
#       5 rr1=fitsio.read('/Users/jemcclea/Research/DES_DUST/round2/dusthalos/outputs/dust_correlation1_rr_orthonorm-vdust.fits') # random fg x random background
#
# ...

# %%
fig = plt.figure(figsize=(20,10))
r = np.logspace(-2,2.7,10)
av2 = 2.4e-3 * (r/3.06)**(-0.84)

### in log space
ax=fig.add_subplot(121)
ax.errorbar(dd1['meanR'],dd1['kappa']-fr1['kappa'],yerr=dd1['sigma'],label='randFg sub z1')  
ax.errorbar(dd2['meanR'],dd2['kappa']-fr2['kappa'],yerr=dd2['sigma'],label='randFg sub z2')  
ax.errorbar(dd3['meanR'],dd3['kappa']-fr3['kappa'],yerr=dd3['sigma'],label='randFg sub z3')  
ax.errorbar(dd4['meanR'],dd4['kappa']-fr4['kappa'],yerr=dd4['sigma'],label='randFg sub z4')  
ax.errorbar(dd5['meanR'],dd5['kappa']-fr5['kappa'],yerr=dd5['sigma'],label='randFg sub z5')
ax.plot(r,av2,label='Menard (2010) for z=0.15')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim(1e-7,5e-1)
ax.set_xlim(0.1,250)
ax.legend()

### in linear space
ax2=fig.add_subplot(122)
ax2.errorbar(dd1['meanR'],dd1['kappa']-fr1['kappa'],yerr=dd1['sigma'],label='randFg sub z1')  
ax2.errorbar(dd2['meanR'],dd2['kappa']-fr2['kappa'],yerr=dd2['sigma'],label='randFg sub z2')  
ax2.errorbar(dd3['meanR'],dd3['kappa']-fr3['kappa'],yerr=dd3['sigma'],label='randFg sub z3')  
ax2.errorbar(dd4['meanR'],dd4['kappa']-fr4['kappa'],yerr=dd4['sigma'],label='randFg sub z4')  
ax2.errorbar(dd5['meanR'],dd5['kappa']-fr5['kappa'],yerr=dd5['sigma'],label='randFg sub z5')
ax2.plot(r,av2,label='Menard (2010) for z=0.15')
ax2.set_xscale('log')
ax2.set_ylim(-0.05,0.2)
ax2.set_xlim(0.1,250)
ax2.legend()
plt.savefig('dustCorr_scos_zbins.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-9a8e54720b34> in <module>()
#       6 ax=fig.add_subplot(121)
#       7 ax.errorbar(dd1['meanR'],dd1['kappa']-fr1['kappa'],yerr=dd1['sigma'],label='randFg sub z1')
# ----> 8 ax.errorbar(dd2['meanR'],dd2['kappa']-fr2['kappa'],yerr=dd2['sigma'],label='randFg sub z2')
#       9 ax.errorbar(dd3['meanR'],dd3['kappa']-fr3['kappa'],yerr=dd3['sigma'],label='randFg sub z3')
#      10 ax.errorbar(dd4['meanR'],dd4['kappa']-fr4['kappa'],yerr=dd4['sigma'],label='randFg sub z4')
#
# NameError: name 'dd2' is not defined
